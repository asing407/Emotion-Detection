# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# Directory  /Users/anshumaansingh /.deepface created
# Directory  /Users/anshumaansingh /.deepface/weights created

# %%
img = cv2.imread('shock.jpeg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.86it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.472070403941983e-10,
#   'disgust': 1.468558849626886e-18,
#   'fear': 8.910569135878177e-05,
#   'happy': 1.9002315276850368e-07,
#   'sad': 2.68640443218862e-14,
#   'surprise': 99.99991655349731,
#   'neutral': 1.8212165478281987e-22},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 203, 'y': 68, 'w': 127, 'h': 127},
#  'age': 26,
#  'gender': 'Man',
#  'race': {'asian': 0.06032988312654197,
#   'indian': 6.4208365976810455,
#   'black': 0.2362316707149148,
#   'white': 22.661031782627106,
#   'middle eastern': 55.11309504508972,
#   'latino hispanic': 15.508471429347992},
#  'dominant_race': 'middle eastern'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'surprise'

# %%
predictions['dominant_race']
# Out:
# 'middle eastern'

# %%
# We are trying to draw a rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
    
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    #use putText() method for
    # inserting text on video
cv2.putText(img,predictions['dominant_emotion'],
            (50,50),
            font,3,
            (0,255,0),
            2,
            cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
